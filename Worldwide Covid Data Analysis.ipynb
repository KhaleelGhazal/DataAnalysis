# %% [markdown]
# # Wordwide covid data analysis by Khaleel Ghazal and Henry Sogbanmu

# %%
import numpy as np #ALIASING
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\user\\Downloads\\covid_worldwide.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20656\1765211225.py in <module>
# ----> 1 df = pd.read_csv("C:\\Users\\user\\Downloads\\covid_worldwide.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df

# %%
# sample = pd.read_csv("C:/Users/user/Downloads/covid_worldwide.csv")

# %%
# sample
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
#pointing around
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    object
#  3   Total Deaths     225 non-null    object
#  4   Total Recovered  210 non-null    object
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 14.6+ KB

# %%
df.describe() #statistical info about numerical columns
# Out:
#        Serial Number
# count     231.000000
# mean      116.000000
# std        66.828138
# min         1.000000
# 25%        58.500000
# 50%       116.000000
# 75%       173.500000
# max       231.000000

# %%
df.columns
# Out:
# Index(['Serial Number', 'Country', 'Total Cases', 'Total Deaths',
#        'Total Recovered', 'Active Cases', 'Total Test', 'Population'],
#       dtype='object')

# %%
df.shape
# Out:
# (231, 8)

# %%
df
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
df["Total Cases"]
# Out:
# 0      104,196,861
# 1       44,682,784
# 2       39,524,311
# 3       37,779,833
# 4       36,824,580
#           ...
# 226            712
# 227             29
# 228             10
# 229              9
# 230              5
# Name: Total Cases, Length: 231, dtype: object

# %%
df["Country"][24]
# Out:
# 'Portugal'

# %%
df.at[24, "Country"]
# Out:
# 'Portugal'

# %%
df.Country
# Out:
# 0                   USA
# 1                 India
# 2                France
# 3               Germany
# 4                Brazil
#              ...
# 226    Diamond Princess
# 227        Vatican City
# 228      Western Sahara
# 229          MS Zaandam
# 230             Tokelau
# Name: Country, Length: 231, dtype: object

# %%
population_df = df[["Country", "Population"]]

# %%
population_df
# Out:
#               Country     Population
# 0                 USA    334,805,269
# 1               India  1,406,631,776
# 2              France     65,584,518
# 3             Germany     83,883,596
# 4              Brazil    215,353,593
# ..                ...            ...
# 226  Diamond Princess            NaN
# 227      Vatican City            799
# 228    Western Sahara        626,161
# 229        MS Zaandam            NaN
# 230           Tokelau          1,378
#
# [231 rows x 2 columns]

# %%
myrow = df.loc[3:9]
myrow
# Out:
#    Serial Number   Country Total Cases Total Deaths Total Recovered  \
# 3              4   Germany  37,779,833      165,711      37,398,100
# 4              5    Brazil  36,824,580      697,074      35,919,372
# 5              6     Japan  32,588,442       68,399      21,567,425
# 6              7  S. Korea  30,197,066       33,486      29,740,877
# 7              8     Italy  25,453,789      186,833      25,014,986
# 8              9        UK  24,274,361      204,171      24,020,088
# 9             10    Russia  21,958,696      395,108      21,356,008
#
#   Active Cases   Total Test   Population
# 3      216,022  122,332,384   83,883,596
# 4      208,134   63,776,166  215,353,593
# 5   10,952,618   92,144,639  125,584,838
# 6      422,703   15,804,065   51,329,899
# 7      251,970  265,478,247   60,262,770
# 8       50,102  522,526,476   68,497,907
# 9      207,580  273,400,000  145,805,947

# %%
df.head(5)
# Out:
#    Serial Number  Country  Total Cases Total Deaths Total Recovered  \
# 0              1      USA  104,196,861    1,132,935     101,322,779
# 1              2    India   44,682,784      530,740      44,150,289
# 2              3   France   39,524,311      164,233      39,264,546
# 3              4  Germany   37,779,833      165,711      37,398,100
# 4              5   Brazil   36,824,580      697,074      35,919,372
#
#   Active Cases     Total Test     Population
# 0    1,741,147  1,159,832,679    334,805,269
# 1        1,755    915,265,788  1,406,631,776
# 2       95,532    271,490,188     65,584,518
# 3      216,022    122,332,384     83,883,596
# 4      208,134     63,776,166    215,353,593

# %%
df.tail(5)
# Out:
#      Serial Number           Country Total Cases Total Deaths Total Recovered  \
# 226            227  Diamond Princess         712           13             699
# 227            228      Vatican City          29          NaN              29
# 228            229    Western Sahara          10            1               9
# 229            230        MS Zaandam           9            2               7
# 230            231           Tokelau           5          NaN             NaN
#
#     Active Cases Total Test Population
# 226            0        NaN        NaN
# 227            0        NaN        799
# 228            0        NaN    626,161
# 229            0        NaN        NaN
# 230            5        NaN      1,378

# %%
df.sample(10)
# Out:
#      Serial Number          Country Total Cases Total Deaths Total Recovered  \
# 174            175      Timor-Leste      23,415          138          23,102
# 65              66          Tunisia   1,150,356       29,308             NaN
# 41              42           Sweden   2,693,458       23,246       2,658,039
# 192            193           Gambia      12,586          372          12,189
# 167            168   Cayman Islands      31,472           37           8,553
# 130            131  Channel Islands     101,116          223         100,778
# 117            118       Guadeloupe     201,394        1,007             NaN
# 5                6            Japan  32,588,442       68,399      21,567,425
# 105            106           Brunei     275,220          225         243,601
# 172            173  Solomon Islands      24,575          153             NaN
#
#     Active Cases  Total Test   Population
# 174          175     278,529    1,369,429
# ...

# %%
# Cleaning data
df.drop(["Serial Number"], axis = 1, inplace = True)

# %%
df
# Out:
#               Country  Total Cases Total Deaths Total Recovered Active Cases  \
# 0                 USA  104,196,861    1,132,935     101,322,779    1,741,147
# 1               India   44,682,784      530,740      44,150,289        1,755
# 2              France   39,524,311      164,233      39,264,546       95,532
# 3             Germany   37,779,833      165,711      37,398,100      216,022
# 4              Brazil   36,824,580      697,074      35,919,372      208,134
# ..                ...          ...          ...             ...          ...
# 226  Diamond Princess          712           13             699            0
# 227      Vatican City           29          NaN              29            0
# 228    Western Sahara           10            1               9            0
# 229        MS Zaandam            9            2               7            0
# 230           Tokelau            5          NaN             NaN            5
#
#         Total Test     Population
# ...

# %%
#Handling missing values
#a. finding missing values
df.isna()
df.isna().any()
df.isna().sum()
# Out:
# Country             0
# Total Cases         0
# Total Deaths        6
# Total Recovered    21
# Active Cases       19
# Total Test         18
# Population          3
# dtype: int64

# %%
df.shape
# Out:
# (231, 7)

# %%
#Dropping null values
de = df.dropna(axis = 0, how="any")
de.shape
de
# Out:
#                    Country  Total Cases Total Deaths Total Recovered  \
# 0                      USA  104,196,861    1,132,935     101,322,779
# 1                    India   44,682,784      530,740      44,150,289
# 2                   France   39,524,311      164,233      39,264,546
# 3                  Germany   37,779,833      165,711      37,398,100
# 4                   Brazil   36,824,580      697,074      35,919,372
# ..                     ...          ...          ...             ...
# 217               Anguilla        3,904           12           3,879
# 218                  Macao        3,488          120           3,357
# 219  Saint Pierre Miquelon        3,452            2           2,449
# 220      Wallis and Futuna        3,427            7             438
# 224             Montserrat        1,403            8           1,376
#
#     Active Cases     Total Test     Population
# 0      1,741,147  1,159,832,679    334,805,269
# ...

# %%
# Replace missing values
dg = df.fillna(905)
dg
# Out:
#               Country  Total Cases Total Deaths Total Recovered Active Cases  \
# 0                 USA  104,196,861    1,132,935     101,322,779    1,741,147
# 1               India   44,682,784      530,740      44,150,289        1,755
# 2              France   39,524,311      164,233      39,264,546       95,532
# 3             Germany   37,779,833      165,711      37,398,100      216,022
# 4              Brazil   36,824,580      697,074      35,919,372      208,134
# ..                ...          ...          ...             ...          ...
# 226  Diamond Princess          712           13             699            0
# 227      Vatican City           29          905              29            0
# 228    Western Sahara           10            1               9            0
# 229        MS Zaandam            9            2               7            0
# 230           Tokelau            5          905             905            5
#
#         Total Test     Population
# ...

# %%
mean = df.Population.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-bb206ea047e0> in <module>
# ----> 1 mean = df.Population.mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
# ...

# %%
df["Population"] = pd.to_numeric(df["Population"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "334,805,269"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-498ae5f1cf92> in <module>
# ----> 1 df["Population"] = pd.to_numeric(df["Population"])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
df.replace(",", "", regex = True, inplace = True)

# %%
df
# Out:
#               Country Total Cases Total Deaths Total Recovered Active Cases  \
# 0                 USA   104196861      1132935       101322779      1741147
# 1               India    44682784       530740        44150289         1755
# 2              France    39524311       164233        39264546        95532
# 3             Germany    37779833       165711        37398100       216022
# 4              Brazil    36824580       697074        35919372       208134
# ..                ...         ...          ...             ...          ...
# 226  Diamond Princess         712           13             699            0
# 227      Vatican City          29          NaN              29            0
# 228    Western Sahara          10            1               9            0
# 229        MS Zaandam           9            2               7            0
# 230           Tokelau           5          NaN             NaN            5
#
#      Total Test  Population
# ...

# %%
dg = df.copy()
dg["Population"] = pd.to_numeric(dg["Population"])
mean = dg.Population.mean()
dg["Population"].fillna(mean, inplace = True)
dg
# Out:
#               Country Total Cases Total Deaths Total Recovered Active Cases  \
# 0                 USA   104196861      1132935       101322779      1741147
# 1               India    44682784       530740        44150289         1755
# 2              France    39524311       164233        39264546        95532
# 3             Germany    37779833       165711        37398100       216022
# 4              Brazil    36824580       697074        35919372       208134
# ..                ...         ...          ...             ...          ...
# 226  Diamond Princess         712           13             699            0
# 227      Vatican City          29          NaN              29            0
# 228    Western Sahara          10            1               9            0
# 229        MS Zaandam           9            2               7            0
# 230           Tokelau           5          NaN             NaN            5
#
#      Total Test    Population
# ...

# %%
df.dropna(axis = 0, how = "any", inplace = True)
df
# Out:
#                    Country Total Cases Total Deaths Total Recovered  \
# 0                      USA   104196861      1132935       101322779
# 1                    India    44682784       530740        44150289
# 2                   France    39524311       164233        39264546
# 3                  Germany    37779833       165711        37398100
# 4                   Brazil    36824580       697074        35919372
# ..                     ...         ...          ...             ...
# 217               Anguilla        3904           12            3879
# 218                  Macao        3488          120            3357
# 219  Saint Pierre Miquelon        3452            2            2449
# 220      Wallis and Futuna        3427            7             438
# 224             Montserrat        1403            8            1376
#
#     Active Cases  Total Test  Population
# 0        1741147  1159832679   334805269
# 1           1755   915265788  1406631776
# ...

# %%
# Sorting
df.sort_values("Population", inplace = True)

# %%
df
# Out:
#                  Country Total Cases Total Deaths Total Recovered  \
# 68                   UAE     1049409         2348         1032735
# 24              Portugal     5563907        26022         5532366
# 189             Djibouti       15690          189           15427
# 41                Sweden     2693458        23246         2658039
# 76            Azerbaijan      827944        10085          817654
# ..                   ...         ...          ...             ...
# 73               Belarus      994037         7118          985592
# 132                  DRC       95514         1463           84264
# 45               Hungary     2192447        48677         2139857
# 12               Vietnam    11526508        43186        10612479
# 202  Antigua and Barbuda        9106          146            8954
#
#     Active Cases Total Test Population
# 68         14326  198638806   10081785
# 24          5519   45915651   10140570
# 189           74     305941    1016097
# ...

# %%
df.head(20)
# Out:
#                     Country Total Cases Total Deaths Total Recovered  \
# 68                      UAE     1049409         2348         1032735
# 24                 Portugal     5563907        26022         5532366
# 189                Djibouti       15690          189           15427
# 41                   Sweden     2693458        23246         2658039
# 76               Azerbaijan      827944        10085          817654
# 50                   Jordan     1746997        14122         1731007
# 23                   Greece     5708301        35630         5662212
# 88                    Egypt      515645        24613          442182
# 32                  Czechia     4590019        42312         4538304
# 155                   Aruba       43993          236           42438
# 185                   Tonga       16734           13           15638
# 216                   Nauru        4621            1            4609
# 220       Wallis and Futuna        3427            7             438
# ...

# %%
df.sort_values("Country", inplace = True)
df
# Out:
#                Country Total Cases Total Deaths Total Recovered Active Cases  \
# 114        Afghanistan      208545         7882          186088        14575
# 101            Albania      334167         3595          328951         1621
# 106            Algeria      271378         6881          182749        81748
# 152            Andorra       47839          165           47563          111
# 129             Angola      105184         1931          103216           37
# ..                 ...         ...          ...             ...          ...
# 12             Vietnam    11526508        43186        10612479       870843
# 220  Wallis and Futuna        3427            7             438         2982
# 196              Yemen       11945         2159            9124          662
# 100             Zambia      340763         4047          335104         1612
# 108           Zimbabwe      261606         5652          254951         1003
#
#     Total Test Population
# ...

# %%
df["Total Cases"] = pd.to_numeric(df["Total Cases"])
df["Total Deaths"] = pd.to_numeric(df["Total Deaths"])
df["Total Recovered"] = pd.to_numeric(df["Total Recovered"])
df["Active Cases"] = pd.to_numeric(df["Active Cases"])
df["Total Test"] = pd.to_numeric(df["Total Test"])
df["Population"] = pd.to_numeric(df["Population"])

# %%
total_cases = df["Total Cases"].sum()
total_deaths = df["Total Deaths"].sum()

print("Total cases: {:,} \nTotal deaths: {:,}".format(total_cases, total_deaths))
# Out:
# Total cases: 649,205,332
# Total deaths: 6,588,473

# %%
death_rate = total_deaths/total_cases
print("Death rate: {:.2f}".format(death_rate/100))
# Out:
# Death rate: 0.00

# %%
serious_active_cases_df = df["Active Cases"]>50000
sac = df[serious_active_cases_df].sort_values("Active Cases")
sac
# Out:
#            Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 8               UK     24274361        204171         24020088         50102
# 11           Spain     13731478        118434         13557699         55345
# 33          Canada      4550256         50380          4444013         55863
# 122         Uganda       170400          3630           100431         66339
# 93         Réunion       485895           919           418572         66404
# 44       Singapore      2217110          1722          2144490         70898
# 106        Algeria       271378          6881           182749         81748
# 17            Iran      7564350        144749          7337549         82052
# 86         Moldova       598673         11953           504142         82578
# 85         Estonia       613891          2912           524990         85989
# 131  French Guiana        98028           420            11254         86354
# ...

# %%
df["Virulence"] = df["Total Cases"]/ df["Total Test"]
df
# Out:
#                Country  Total Cases  Total Deaths  Total Recovered  \
# 114        Afghanistan       208545          7882           186088
# 101            Albania       334167          3595           328951
# 106            Algeria       271378          6881           182749
# 152            Andorra        47839           165            47563
# 129             Angola       105184          1931           103216
# ..                 ...          ...           ...              ...
# 12             Vietnam     11526508         43186         10612479
# 220  Wallis and Futuna         3427             7              438
# 196              Yemen        11945          2159             9124
# 100             Zambia       340763          4047           335104
# 108           Zimbabwe       261606          5652           254951
#
#      Active Cases  Total Test  Population  Virulence
# 114         14575     1188898    40754388   0.175410
# 101          1621     1941032     2866374   0.172159
# ...

# %%
df.to_csv("stubborn.csv", index= None)

# %%
a = [1,2,3,4,5]
plt.plot(a);

# %%
a = [1,2,3,4,5]
b = [2020, 2021, 2022, 2023, 2024]
plt.plot(b, a)
plt.xlabel("Years")
plt.ylabel("Values");

# %%
sns.set_style("darkgrid")
a = [1,2,3,4,5]
b = [2020, 2021, 2022, 2023, 2024]
c = [11,22,33,44,55]
plt.plot(b, a, marker = "o")
plt.plot(b,c, marker = "x")
plt.xlabel("Years")
plt.ylabel("Values")

plt.title("Has anyone eaten?")
plt.legend(["This", "That"])

# %%
sns.set_style("darkgrid")
plt.figure(figsize = (12,9))
sns.scatterplot(x = sac["Population"], y = sac["Total Cases"], hue = sac["Country"], s = 100)
plt.xlabel("Population")
plt.ylabel("Total cases")
plt.title("FINAL PLOT OF THE DAY")
# Out:
# Text(0.5, 1.0, 'FINAL PLOT OF THE DAY')

# %%
correlation  = data.corr()
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)

# %%
sns.pairplot(data)
sns.relplot(data = data, x= "columna", y = "columnb", hue = "lunch")
